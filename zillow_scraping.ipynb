# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = 'https://www.zillow.com/homes/for_sale/52-EAST-PASSAIC-AVENUE-BLOOMFIELD-NJ-07003_rb/'

# Using a browser mechanism to scrapping Zillow
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36'}

# Get the response from Zillow and use a BeautifulSoup Object
response = requests.get(url, headers=headers)
result = BeautifulSoup(response.content,'lxml')
result
# Out:
# <!DOCTYPE html>
# <html class="wf-loading no-js zsg-theme-modernized zsg-lightbox_scroll" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/product#">
# <head>
# ...

# %%
address = '26 JOSEPH ST NEWARK NJ 07105'

# Generate the the appropriate url for Zillow to do the search
def get_zillow_url(address):
    address = address.replace(' ','-')
    url = 'https://www.zillow.com/homes/for_sale/' + address + '_rb/'
    return url

# %%
url = get_zillow_url(address)
info = {}

# Using a browser mechanism to scrapping Zillow
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36'}

# Get the response from Zillow and use a BeautifulSoup Object
response = requests.get(url, headers=headers)
result = BeautifulSoup(response.content,'lxml')

# Given the address of the house, find the number of bedrooms, bathrooms, size and year built for the house
bedroom_num = result.find('h3', 'edit-facts-light').find_all('span', {'class' : None})[0].get_text().split(' ')[0]
bathroom_num = result.find('h3', 'edit-facts-light').find_all('span', {'class' : None})[1].get_text().split(' ')[0]
size = result.find('h3', 'edit-facts-light').find_all('span', {'class' : None})[2].get_text().split(' ')[0]
year_built = result.find_all('div', {'class': 'fact-value'})[1].get_text()

# Put the above data to a dict created
info['Bedroom'] = bedroom_num
info['Bathroom'] = bathroom_num
info['Size'] = size
info['Year Built'] = year_built

# Get all the divs tags within the page
divs_text = ''
all_divs = result.find_all('div', {'class': 'fact-value'})
for div in all_divs:
    text = div.get_text()
    divs_text += text + ' '

# Define a Regex expression to find the last sold year and price for the house
pattern = r'\w{3} \d{4} \w{3} \S+'
match = re.findall(pattern, divs_text)

# Get the last sold year and price for the house, put these data to a dict created
last_sold_year = match[0].split(' ')[1]
last_sold_price = match[0].split(' ')[3]
info['Last Sold Year'] = last_sold_year
info['Last Sold Price'] = last_sold_price

# %%
info
# Out:
# {'Bathroom': '2',
#  'Bedroom': '3',
#  'Last Sold Price': '$150,000',
#  'Last Sold Year': '2005',
#  'Size': '1,160',
#  'Year Built': '1890'}
